# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re

# Load your CSV files
models_df = pd.read_csv(r"C:\Users\Administrator\Desktop\code\band to parameter\linear regression\linear regression sentinel\srp_lr.csv")
variables_df = pd.read_csv(r"C:\Users\Administrator\Desktop\code\band to band\sentinel 2\sentinel_bandratios_ratios.csv")
y_values_df = pd.read_csv(r"C:\Users\Administrator\Desktop\code\band to band\sentinel 2\sparameters.csv")

# Create a directory to save plots
os.makedirs("regression_plots", exist_ok=True)

# Safe filename function
def safe_filename(name):
    return re.sub(r'[^\w\-_.]', '_', str(name))

# Iterate over each model
for index, row in models_df.iterrows():
    feature = row['Feature']
    target = row['Target']
    slope = row['Slope']
    intercept = row['Intercept']
    r_squared = row.get('R_squared', None)
    rmse = row.get('RMSE', None)

    if feature not in variables_df.columns or target not in y_values_df.columns:
        print(f"Skipping model {index}: '{feature}' or '{target}' not found.")
        continue

    # Extract X and Y
    x = variables_df[feature]
    y = y_values_df[target]

    # Calculate regression line
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = slope * x_line + intercept

    # Plot
    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, color='blue', label='Actual Data')
    plt.plot(x_line, y_line, color='red', label='Regression Line')
    plt.title(f"Regression: {target} vs {feature}")
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.legend()
    plt.grid(True)

    # Annotate with model stats
    annotation = f"Slope: {slope:.3f}\nIntercept: {intercept:.3f}"
    if r_squared is not None:
        annotation += f"\nR²: {r_squared:.3f}"
    if rmse is not None:
        annotation += f"\nRMSE: {rmse:.3f}"
    plt.text(0.05, 0.95, annotation, transform=plt.gca().transAxes,
             verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))

    # Save plot
    safe_feature = safe_filename(feature)
    safe_target = safe_filename(target)
    plot_filename = f"regression_plots/{safe_target}_vs_{safe_feature}.png"
    plt.savefig(plot_filename)
    plt.close()
    print(f"Saved plot: {plot_filename}")
# Out:
# Saved plot: regression_plots/pH_vs__B2_B6.png
# Saved plot: regression_plots/pH_vs__B2_B7.png
# Saved plot: regression_plots/pH_vs__B2_B8A.png
# Saved plot: regression_plots/pH_vs__B3_B4.png
# Saved plot: regression_plots/Alkalinity_vs__B3_B7.png
# Saved plot: regression_plots/pH_vs__B4_B3.png
# Saved plot: regression_plots/EC_vs__B4_B5.png
# Saved plot: regression_plots/TDS_vs__B4_B5.png
# Saved plot: regression_plots/pH_vs__B5_B4.png
# Saved plot: regression_plots/EC_vs__B5_B4.png
# Saved plot: regression_plots/TDS_vs__B5_B4.png
# Saved plot: regression_plots/pH_vs__B6_B2.png
# Saved plot: regression_plots/pH_vs__B7_B2.png

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re

# Load your CSV files
models_df = pd.read_csv(r"C:\Users\Administrator\Desktop\code\band to parameter\linear regression\linear regression sentinel\slcp_lr.csv")
variables_df = pd.read_csv(r"C:\Users\Administrator\Desktop\code\band to band\sentinel 2\sentinel_linearcombinations4_evaluated.csv")
y_values_df = pd.read_csv(r"C:\Users\Administrator\Desktop\code\band to band\sentinel 2\sparameters.csv")

# Create a directory to save plots
os.makedirs("regression_plots", exist_ok=True)

# Safe filename function
def safe_filename(name):
    return re.sub(r'[^\w\-_.]', '_', str(name))

# Iterate over each model
for index, row in models_df.iterrows():
    feature = row['Feature']
    target = row['Target']
    slope = row['Slope']
    intercept = row['Intercept']
    r_squared = row.get('R_squared', None)
    rmse = row.get('RMSE', None)

    if feature not in variables_df.columns or target not in y_values_df.columns:
        print(f"Skipping model {index}: '{feature}' or '{target}' not found.")
        continue

    # Extract X and Y
    x = variables_df[feature]
    y = y_values_df[target]

    # Calculate regression line
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = slope * x_line + intercept

    # Plot
    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, color='blue', label='Actual Data')
    plt.plot(x_line, y_line, color='red', label='Regression Line')
    plt.title(f"Regression: {target} vs {feature}")
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.legend()
    plt.grid(True)

    # Annotate with model stats
    annotation = f"Slope: {slope:.3f}\nIntercept: {intercept:.3f}"
    if r_squared is not None:
        annotation += f"\nR²: {r_squared:.3f}"
    if rmse is not None:
        annotation += f"\nRMSE: {rmse:.3f}"
    plt.text(0.05, 0.95, annotation, transform=plt.gca().transAxes,
             verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))

    # Save plot
    safe_feature = safe_filename(feature)
    safe_target = safe_filename(target)
    plot_filename = f"regression_plots/{safe_target}_vs_{safe_feature}.png"
    plt.savefig(plot_filename)
    plt.close()
    print(f"Saved plot: {plot_filename}")
# Out:
# Saved plot: regression_plots/pH_vs__B4-B5.png
# Saved plot: regression_plots/pH_vs__-B4_B5.png
# Saved plot: regression_plots/pH_vs__B3-B4-B11.png
# Saved plot: regression_plots/pH_vs__-B3_B4_B11.png
# Saved plot: regression_plots/pH_vs__B3-B5-B11.png
# Saved plot: regression_plots/pH_vs__-B3_B5_B11.png
# Saved plot: regression_plots/pH_vs__B1-B2-B3_B5.png
# Saved plot: regression_plots/pH_vs__-B1_B2_B3-B5.png
# Saved plot: regression_plots/pH_vs__B3-B5-B11_B12.png
# Saved plot: regression_plots/pH_vs__B3-B5-B11-B12.png
# Saved plot: regression_plots/pH_vs__-B3_B5_B11_B12.png
# Saved plot: regression_plots/pH_vs__-B3_B5_B11-B12.png
# Saved plot: regression_plots/pH_vs__B4-B5-B6_B8A.png
# Saved plot: regression_plots/pH_vs__-B4_B5_B6-B8A.png
# Saved plot: regression_plots/pH_vs__B4-B5-B7_B8A.png
# Saved plot: regression_plots/pH_vs__-B4_B5_B7-B8A.png

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re

# Load your CSV files
models_df = pd.read_csv(r"C:\Users\Administrator\Desktop\code\band to parameter\linear regression\linear regression sentinel\s2lrp_lr.csv")
variables_df = pd.read_csv(r"C:\Users\Administrator\Desktop\code\band to band\sentinel 2\sentinel_2bandcombratios_ratios.csv")
y_values_df = pd.read_csv(r"C:\Users\Administrator\Desktop\code\band to band\sentinel 2\sparameters.csv")

# Create a directory to save plots
os.makedirs("regression_plots", exist_ok=True)

# Safe filename function
def safe_filename(name):
    return re.sub(r'[^\w\-_.]', '_', str(name))

# Iterate over each model
for index, row in models_df.iterrows():
    feature = row['Feature']
    target = row['Target']
    slope = row['Slope']
    intercept = row['Intercept']
    r_squared = row.get('R_squared', None)
    rmse = row.get('RMSE', None)

    if feature not in variables_df.columns or target not in y_values_df.columns:
        print(f"Skipping model {index}: '{feature}' or '{target}' not found.")
        continue

    # Extract X and Y
    x = variables_df[feature]
    y = y_values_df[target]

    # Calculate regression line
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = slope * x_line + intercept

    # Plot
    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, color='blue', label='Actual Data')
    plt.plot(x_line, y_line, color='red', label='Regression Line')
    plt.title(f"Regression: {target} vs {feature}")
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.legend()
    plt.grid(True)

    # Annotate with model stats
    annotation = f"Slope: {slope:.3f}\nIntercept: {intercept:.3f}"
    if r_squared is not None:
        annotation += f"\nR²: {r_squared:.3f}"
    if rmse is not None:
        annotation += f"\nRMSE: {rmse:.3f}"
    plt.text(0.05, 0.95, annotation, transform=plt.gca().transAxes,
             verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))

    # Save plot
    safe_feature = safe_filename(feature)
    safe_target = safe_filename(target)
    plot_filename = f"regression_plots/{safe_target}_vs_{safe_feature}.png"
    plt.savefig(plot_filename)
    plt.close()
    print(f"Saved plot: {plot_filename}")
# Out:
# Saved plot: regression_plots/Temperatur_vs__B3-B5_-B1_B4.png
# Saved plot: regression_plots/Temperatur_vs__-B3_B5_-B1_B4.png
# Saved plot: regression_plots/Temperatur_vs__B4-B6_B5-B7.png
# Saved plot: regression_plots/Temperatur_vs__B4-B6_-B5_B7.png
# Saved plot: regression_plots/Temperatur_vs__-B4_B6_B5-B7.png
# Saved plot: regression_plots/Temperatur_vs__-B4_B6_-B5_B7.png
